# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/Users/dipeshkumar/Downloads/titanic.csv')

# %%
data
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
data.drop(['name','sibsp','parch','ticket','cabin','embarked','boat','body','home.dest'],axis='columns',inplace=True)

# %%
data
# Out:
#       pclass  survived     sex      age      fare
# 0        1.0       1.0  female  29.0000  211.3375
# 1        1.0       1.0    male   0.9167  151.5500
# 2        1.0       0.0  female   2.0000  151.5500
# 3        1.0       0.0    male  30.0000  151.5500
# 4        1.0       0.0  female  25.0000  151.5500
# ...      ...       ...     ...      ...       ...
# 1305     3.0       0.0  female      NaN   14.4542
# 1306     3.0       0.0    male  26.5000    7.2250
# 1307     3.0       0.0    male  27.0000    7.2250
# 1308     3.0       0.0    male  29.0000    7.8750
# 1309     NaN       NaN     NaN      NaN       NaN
#
# [1310 rows x 5 columns]

# %%
target = data.survived
inputs = data.drop(['survived'],axis='columns')

# %%
dummies = pd.get_dummies(inputs.sex)

# %%
dummies.head()
# Out:
#    female  male
# 0       1     0
# 1       0     1
# 2       1     0
# 3       0     1
# 4       1     0

# %%
inputs = pd.concat([inputs,dummies],axis='columns')
inputs.head()
# Out:
#    pclass     sex      age      fare  female  male
# 0     1.0  female  29.0000  211.3375       1     0
# 1     1.0    male   0.9167  151.5500       0     1
# 2     1.0  female   2.0000  151.5500       1     0
# 3     1.0    male  30.0000  151.5500       0     1
# 4     1.0  female  25.0000  151.5500       1     0

# %%
inputs.drop('sex',axis='columns')
# Out:
#       pclass      age      fare  female  male
# 0        1.0  29.0000  211.3375       1     0
# 1        1.0   0.9167  151.5500       0     1
# 2        1.0   2.0000  151.5500       1     0
# 3        1.0  30.0000  151.5500       0     1
# 4        1.0  25.0000  151.5500       1     0
# ...      ...      ...       ...     ...   ...
# 1305     3.0      NaN   14.4542       1     0
# 1306     3.0  26.5000    7.2250       0     1
# 1307     3.0  27.0000    7.2250       0     1
# 1308     3.0  29.0000    7.8750       0     1
# 1309     NaN      NaN       NaN       0     0
#
# [1310 rows x 5 columns]

# %%
inputs.columns[inputs.isna().any()]
# Out:
# Index(['pclass', 'sex', 'age', 'fare'], dtype='object')

# %%
inputs.age = inputs.age.fillna(inputs.age.mean())

# %%
inputs
# Out:
#       pclass     sex        age      fare  female  male
# 0        1.0  female  29.000000  211.3375       1     0
# 1        1.0    male   0.916700  151.5500       0     1
# 2        1.0  female   2.000000  151.5500       1     0
# 3        1.0    male  30.000000  151.5500       0     1
# 4        1.0  female  25.000000  151.5500       1     0
# ...      ...     ...        ...       ...     ...   ...
# 1305     3.0  female  29.881135   14.4542       1     0
# 1306     3.0    male  26.500000    7.2250       0     1
# 1307     3.0    male  27.000000    7.2250       0     1
# 1308     3.0    male  29.000000    7.8750       0     1
# 1309     NaN     NaN  29.881135       NaN       0     0
#
# [1310 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,y_train,x_test,y_test = train_test_split(inputs,target,test_size=0.2)

# %%
len(x_train)
# Out:
# 1048

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
model.fit(x_train,y_train)

# %%
model.score(x_test)

# %%
model.predict(x_test)
